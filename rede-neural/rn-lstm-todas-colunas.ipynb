# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
import matplotlib.pyplot as plt

# Carregando o dataset (ajuste o caminho do arquivo CSV conforme necessário)
df = pd.read_csv('base_unificada_ate_2015.csv')

# Lista de países únicos no dataset
paises = df['Local'].unique()

# Função para criar os conjuntos de dados de treinamento e teste
def create_dataset(features, target, n_steps):
    X, y = [], []
    for i in range(len(features) - n_steps):
        X.append(features[i:i + n_steps])
        y.append(target[i + n_steps])
    return np.array(X), np.array(y)

# Número de passos de tempo para olhar para trás
n_steps = 5

# Armazenar previsões e acurácia por país
previsoes_paises = {}
mse_paises = {}

for pais in paises:
    # Filtrar os dados para o país
    df_pais = df[df['Local'] == pais]
    
    # Selecionar todas as colunas relevantes (exceto 'Local' e 'Ano') como features
    features = df_pais[['BCG', 'Hib3', 'DTP3', 'Saneamento Seguro (%)', 
                        'Numero Total de Imigrantes', 'Gini (Indice de Desigualdade no Pais)', 
                        'Populacao', 'Taxa de Extrema Pobreza (%)', 'Numero de Usuario de Internet']].values

    # Selecionar a coluna de interesse para prever (número de infecções respiratórias e tuberculose)
    target = df_pais['Numero de Casos de Infeccoes Respiratorios e Tuberculose'].values.reshape(-1, 1)

    # Normalizando os dados (tanto as features quanto o target)
    scaler_features = MinMaxScaler(feature_range=(0, 1))
    scaled_features = scaler_features.fit_transform(features)

    scaler_target = MinMaxScaler(feature_range=(0, 1))
    scaled_target = scaler_target.fit_transform(target)

    # Criando os conjuntos de dados
    X, y = create_dataset(scaled_features, scaled_target, n_steps)

    # Dividindo em conjunto de treinamento e teste (80% para treino, 20% para teste)
    split = int(0.8 * len(X))
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    print(X_train.shape)

    # Reshape para o LSTM [amostras, passos de tempo, características]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], X_train.shape[2]))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], X_test.shape[2]))

    # Modelo LSTM
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=(n_steps, X_train.shape[2])))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Treinando o modelo
    model.fit(X_train, y_train, epochs=200, verbose=0, validation_split=0.1)

    # Fazendo previsões
    y_pred = model.predict(X_test)
    y_pred = scaler_target.inverse_transform(y_pred)
    y_test = scaler_target.inverse_transform(y_test.reshape(-1, 1))

    # Calculando o erro para o país
    mse = mean_squared_error(y_test, y_pred)
    mse_paises[pais] = mse
    print(f'País: {pais} - Mean Squared Error: {mse}')

    # Previsão futura
    last_sequence = scaled_features[-n_steps:]  # Pegando a última sequência para previsão
    predictions = []
    n_features = 9

    for _ in range(5):  # Prever os próximos 5 anos
        last_sequence = last_sequence.reshape((1, n_steps, X_train.shape[2]))  # Ajustando o formato para o modelo
        next_value = model.predict(last_sequence)  # Prevendo o próximo valor
        predictions.append(next_value[0, 0])
        # Atualizando a sequência removendo o primeiro valor e adicionando o próximo valor previsto
        # last_sequence = np.concatenate((last_sequence[:, 1:, :], np.expand_dims(next_value, axis=1)), axis=1)
        next_value_expanded = np.repeat(np.expand_dims(next_value, axis=1), n_features, axis=2)
        last_sequence = np.concatenate((last_sequence[:, 1:, :], next_value_expanded), axis=1)


    # Convertendo as previsões para o formato original
    predictions = scaler_target.inverse_transform(np.array(predictions).reshape(-1, 1))
    previsoes_paises[pais] = predictions.flatten()

    # Exibindo as previsões e o erro para o país
    print(f'\nPaís: {pais}')
    print(f'Acurácia (MSE): {mse}')
    print('Previsões para os próximos 5 anos:')

    inicio_previsao = 2016
    fim_previsao = 2021

    future_years = list(range(inicio_previsao, fim_previsao))
    for year, pred in zip(future_years, previsoes_paises[pais]):
        print(f'Ano: {year} - Previsão: {pred}')

    # Plotando as previsões para o país
    plt.figure(figsize=(14, 8))
    plt.plot(df_pais['Ano'], df_pais['Numero de Casos de Infeccoes Respiratorios e Tuberculose'], label='Dados Reais')
    plt.plot(future_years, previsoes_paises[pais], label='Previsões Futuras', color='red')
    plt.xlabel('Ano')
    plt.ylabel('Número de Casos de Infecções Respiratórias e Tuberculose')
    plt.title(f'Previsão de Casos de Infecções Respiratórias e Tuberculose para {pais} de {inicio_previsao} até {fim_previsao}')
    plt.legend()
    plt.show()
# Out:
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# País: Albania - Mean Squared Error: 31020589.0546875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# País: Albania
# Acurácia (MSE): 31020589.0546875
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 648117.5625
# Ano: 2017 - Previsão: 656313.4375
# Ano: 2018 - Previsão: 660459.375
# Ano: 2019 - Previsão: 663067.4375
# Ano: 2020 - Previsão: 665435.1875
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# País: Algeria - Mean Squared Error: 92149674.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# País: Algeria
# Acurácia (MSE): 92149674.0
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 6021722.5
# Ano: 2017 - Previsão: 6021945.5
# Ano: 2018 - Previsão: 6023177.5
# Ano: 2019 - Previsão: 6023909.0
# Ano: 2020 - Previsão: 6023506.5
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# País: Argentina - Mean Squared Error: 3484949265.3333335
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# País: Argentina
# Acurácia (MSE): 3484949265.3333335
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 10334123.0
# Ano: 2017 - Previsão: 10393371.0
# Ano: 2018 - Previsão: 10494918.0
# Ano: 2019 - Previsão: 10683080.0
# Ano: 2020 - Previsão: 11069299.0
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# País: Armenia - Mean Squared Error: 830690103.3307291
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# País: Armenia
# Acurácia (MSE): 830690103.3307291
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 771859.8125
# Ano: 2017 - Previsão: 777331.0625
# Ano: 2018 - Previsão: 780178.25
# Ano: 2019 - Previsão: 781750.25
# Ano: 2020 - Previsão: 781440.0625
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# País: Austria - Mean Squared Error: 196180777.82421875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# País: Austria
# Acurácia (MSE): 196180777.82421875
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 1030860.9375
# Ano: 2017 - Previsão: 1024371.0625
# Ano: 2018 - Previsão: 1024259.0625
# Ano: 2019 - Previsão: 1025926.0625
# Ano: 2020 - Previsão: 1030802.75
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# País: Denmark - Mean Squared Error: 2459703227.846357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# País: Denmark
# Acurácia (MSE): 2459703227.846357
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 751536.1875
# Ano: 2017 - Previsão: 743950.25
# Ano: 2018 - Previsão: 734947.25
# Ano: 2019 - Previsão: 726930.6875
# Ano: 2020 - Previsão: 720210.0625
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# País: Djibouti - Mean Squared Error: 81785880.36751302
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# País: Djibouti
# Acurácia (MSE): 81785880.36751302
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 275954.4375
# Ano: 2017 - Previsão: 277300.0
# Ano: 2018 - Previsão: 278307.28125
# Ano: 2019 - Previsão: 277531.40625
# Ano: 2020 - Previsão: 277379.0
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# País: Dominican Republic - Mean Squared Error: 916428496.2916745
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# País: Dominican Republic
# Acurácia (MSE): 916428496.2916745
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 3008529.75
# Ano: 2017 - Previsão: 3022402.75
# Ano: 2018 - Previsão: 3031775.25
# Ano: 2019 - Previsão: 3038592.5
# Ano: 2020 - Previsão: 3036445.75
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# País: Ecuador - Mean Squared Error: 4356500656.625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# País: Ecuador
# Acurácia (MSE): 4356500656.625
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 3295439.5
# Ano: 2017 - Previsão: 3295228.0
# Ano: 2018 - Previsão: 3297561.0
# Ano: 2019 - Previsão: 3301644.75
# Ano: 2020 - Previsão: 3307453.75
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# País: Egypt - Mean Squared Error: 345772380832.6667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# País: Egypt
# Acurácia (MSE): 345772380832.6667
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 32428284.0
# Ano: 2017 - Previsão: 33270840.0
# Ano: 2018 - Previsão: 34519744.0
# Ano: 2019 - Previsão: 36111868.0
# Ano: 2020 - Previsão: 38178416.0
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# País: Estonia - Mean Squared Error: 395266370.8561198
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# País: Estonia
# Acurácia (MSE): 395266370.8561198
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 290175.4375
# Ano: 2017 - Previsão: 287768.5625
# Ano: 2018 - Previsão: 285735.46875
# Ano: 2019 - Previsão: 284076.15625
# Ano: 2020 - Previsão: 282577.375
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# País: Ethiopia - Mean Squared Error: 536164603216.3333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# País: Ethiopia
# Acurácia (MSE): 536164603216.3333
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 35397388.0
# Ano: 2017 - Previsão: 35845228.0
# Ano: 2018 - Previsão: 36620468.0
# Ano: 2019 - Previsão: 37735028.0
# Ano: 2020 - Previsão: 39135200.0
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# País: Fiji - Mean Squared Error: 26032571.33951823
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# País: Fiji
# Acurácia (MSE): 26032571.33951823
# Previsões para os próximos 5 anos:
# Ano: 2016 - Previsão: 384191.4375
# Ano: 2017 - Previsão: 388763.34375
# Ano: 2018 - Previsão: 392533.53125
# Ano: 2019 - Previsão: 397033.8125
# Ano: 2020 - Previsão: 402482.03125
# (8, 5, 9)
# /home/aluno/anaconda3/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
