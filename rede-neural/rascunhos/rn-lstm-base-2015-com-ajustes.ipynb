# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Carregando o dataset (ajuste o caminho do arquivo CSV conforme necessário)
df = pd.read_csv('base_unificada_ate_2015.csv')

# Lista de países únicos no dataset
paises = df['Local'].unique()

# Função para criar os conjuntos de dados de treinamento e teste
def create_dataset(series, n_steps):
    X, y = [], []
    for i in range(len(series) - n_steps):
        X.append(series[i:i + n_steps])
        y.append(series[i + n_steps])
    return np.array(X), np.array(y)

# Número de passos de tempo para olhar para trás
n_steps = 3

# Armazenar previsões e acurácia por país
previsoes_paises = {}
mse_paises = {}

for pais in paises:
    # Filtrar os dados para o país
    df_pais = df[df['Local'] == pais]

    # Selecionar a coluna de interesse para prever (número de infecções respiratórias e tuberculose)
    series = df_pais['Numero de Casos de Infeccoes Respiratorios e Tuberculose'].values.reshape(-1, 1)

    # Normalizando os dados
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(series)

    # Criando os conjuntos de dados
    X, y = create_dataset(scaled_data, n_steps)

    # Dividindo em conjunto de treinamento e teste (80% para treino, 20% para teste)
    split = int(0.8 * len(X))
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    # Reshape para o LSTM [amostras, passos de tempo, características]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

    # Modelo LSTM
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=(n_steps, 1)))
    model.add(Dropout(0.2))  # Adicionando dropout após a LSTM
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.3))  # Dropout em camadas densas também pode ser útil
    model.add(Dense(256, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1))  # Nenhuma ativação na saída para previsões contínuas
    # model.add(Dense(10, activation='softmax'))
    opt = Adam(learning_rate=0.001)  # Diminua a taxa de aprendizado se necessário
    model.compile(optimizer=opt, loss='mse')

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    model.fit(X_train, y_train, epochs=200, verbose=0, validation_split=0.1, callbacks=[early_stopping])

    # Treinando o modelo
    # model.fit(X_train, y_train, epochs=400, verbose=0, validation_split=0.1)

    # Fazendo previsões
    y_pred = model.predict(X_test)
    y_pred = scaler.inverse_transform(y_pred)
    y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

    # Calculando o erro para o país
    mse = mean_squared_error(y_test, y_pred)
    mse_paises[pais] = mse
    print(f'País: {pais} - Mean Squared Error: {mse}')

    # Previsão futura
    last_sequence = scaled_data[-n_steps:]  # Pegando a última sequência para previsão
    predictions = []

    for _ in range(5):  # Prever os próximos 10 anos
        last_sequence = last_sequence.reshape((1, n_steps, 1))  # Ajustando o formato para o modelo
        next_value = model.predict(last_sequence)  # Prevendo o próximo valor
        predictions.append(next_value[0, 0])
        # Atualizando a sequência removendo o primeiro valor e adicionando o próximo valor previsto
        last_sequence = np.concatenate((last_sequence[:, 1:, :], np.expand_dims(next_value, axis=1)), axis=1)

    # Convertendo as previsões para o formato original
    predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
    previsoes_paises[pais] = predictions.flatten()

    # Exibindo as previsões e o erro para o país
    print(f'\nPaís: {pais}')
    print(f'Acurácia (MSE): {mse}')
    print('Previsões para os próximos 10 anos:')

    inicio_previsao = 2016
    fim_previsao = 2021

    future_years = list(range(inicio_previsao, fim_previsao))
    for year, pred in zip(future_years, previsoes_paises[pais]):
        print(f'Ano: {year} - Previsão: {pred}')

    # Plotando as previsões para o país
    plt.figure(figsize=(14, 8))
    plt.plot(df_pais['Ano'], df_pais['Numero de Casos de Infeccoes Respiratorios e Tuberculose'], label='Dados Reais')
    plt.plot(future_years, previsoes_paises[pais], label='Previsões Futuras', color='red')
    plt.xlabel('Ano')
    plt.ylabel('Número de Casos de Infecções Respiratórias e Tuberculose')
    plt.title(f'Previsão de Casos de Infecções Respiratórias e Tuberculose para {pais} de {inicio_previsao} até {fim_previsao}')
    plt.legend()
    plt.show()
# Out:
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# País: Brazil
# Acurácia (MSE): 146985654662.66928
# Previsões para os próximos 10 anos:
# Ano: 2016 - Previsão: 64396260.0
# Ano: 2017 - Previsão: 64403112.0
# Ano: 2018 - Previsão: 64436436.0
# Ano: 2019 - Previsão: 64496168.0
# Ano: 2020 - Previsão: 64516784.0
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# País: Bulgaria - Mean Squared Error: 12498528581.614584
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# País: Bulgaria
# Acurácia (MSE): 12498528581.614584
# Previsões para os próximos 10 anos:
# Ano: 2016 - Previsão: 1871800.125
# Ano: 2017 - Previsão: 1877415.125
# Ano: 2018 - Previsão: 1885142.0
# Ano: 2019 - Previsão: 1894447.375
# Ano: 2020 - Previsão: 1896321.75
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# País: Burkina Faso - Mean Squared Error: 3153977570.75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# País: Burkina Faso
# Acurácia (MSE): 3153977570.75
# Previsões para os próximos 10 anos:
# Ano: 2016 - Previsão: 4706574.5
# Ano: 2017 - Previsão: 4714358.0
# Ano: 2018 - Previsão: 4716132.5
# Ano: 2019 - Previsão: 4712493.5
# Ano: 2020 - Previsão: 4713054.0
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# País: Central African Republic - Mean Squared Error: 30777124.23958427
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# País: Central African Republic
# Acurácia (MSE): 30777124.23958427
# Previsões para os próximos 10 anos:
# Ano: 2016 - Previsão: 1924611.375
# Ano: 2017 - Previsão: 1929045.5
# Ano: 2018 - Previsão: 1932623.5
# Ano: 2019 - Previsão: 1934638.75
# Ano: 2020 - Previsão: 1936674.875
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# País: Chad - Mean Squared Error: 3527638.125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# País: Chad
# Acurácia (MSE): 3527638.125
# Previsões para os próximos 10 anos:
# Ano: 2016 - Previsão: 3885590.25
# Ano: 2017 - Previsão: 3897633.75
# Ano: 2018 - Previsão: 3907091.25
# Ano: 2019 - Previsão: 3914473.5
# Ano: 2020 - Previsão: 3920521.5
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# País: Chile - Mean Squared Error: 1793277358.3541973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# País: Chile
# Acurácia (MSE): 1793277358.3541973
# Previsões para os próximos 10 anos:
# Ano: 2016 - Previsão: 3674978.75
# Ano: 2017 - Previsão: 3676590.0
# Ano: 2018 - Previsão: 3679314.0
# Ano: 2019 - Previsão: 3682933.75
# Ano: 2020 - Previsão: 3683649.75
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# País: China - Mean Squared Error: 41317514326910.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# País: China
# Acurácia (MSE): 41317514326910.0
# Previsões para os próximos 10 anos:
# Ano: 2016 - Previsão: 503720320.0
# Ano: 2017 - Previsão: 503605888.0
# Ano: 2018 - Previsão: 504105824.0
# Ano: 2019 - Previsão: 504730720.0
# Ano: 2020 - Previsão: 504995392.0
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# País: Colombia - Mean Squared Error: 32145096071.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# País: Colombia
# Acurácia (MSE): 32145096071.0
# Previsões para os próximos 10 anos:
# Ano: 2016 - Previsão: 13488513.0
# Ano: 2017 - Previsão: 13493930.0
# Ano: 2018 - Previsão: 13506013.0
# Ano: 2019 - Previsão: 13524484.0
# Ano: 2020 - Previsão: 13528630.0
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# País: Costa Rica - Mean Squared Error: 69173744.53125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# País: Costa Rica
# Acurácia (MSE): 69173744.53125
# Previsões para os próximos 10 anos:
# Ano: 2016 - Previsão: 1192899.875
# Ano: 2017 - Previsão: 1193072.375
# Ano: 2018 - Previsão: 1193670.625
# Ano: 2019 - Previsão: 1194682.75
# Ano: 2020 - Previsão: 1194929.125
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# País: Croatia - Mean Squared Error: 1194181536.242189
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# País: Croatia
# Acurácia (MSE): 1194181536.242189
# Previsões para os próximos 10 anos:
# Ano: 2016 - Previsão: 820514.25
# Ano: 2017 - Previsão: 821552.3125
# Ano: 2018 - Previsão: 822942.3125
# Ano: 2019 - Previsão: 824639.5
# Ano: 2020 - Previsão: 824839.25
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# País: Cuba - Mean Squared Error: 2181014776.0416665
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# País: Cuba
# Acurácia (MSE): 2181014776.0416665
# Previsões para os próximos 10 anos:
# Ano: 2016 - Previsão: 2582709.75
# Ano: 2017 - Previsão: 2584033.25
# Ano: 2018 - Previsão: 2586260.0
# Ano: 2019 - Previsão: 2589385.5
# Ano: 2020 - Previsão: 2589832.5
# c:\Users\Fernando\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# País: Cyprus - Mean Squared Error: 1507724.8520507812
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
